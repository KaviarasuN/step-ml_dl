# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#import iris
from sklearn.datasets import load_iris

#load iris datasets
iris = load_iris()

# %%
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Access the features and target variables
X = iris.data
y = iris.target

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'] ,c=y)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Sepal length and Sepal width')
plt.show()

# %%
#Implementing K-means
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
#implement hierarchical
from sklearn.cluster import AgglomerativeClustering
hierarchical = AgglomerativeClustering(n_clusters=3)
hierarchical.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
#import silhouette score for compare the algorithm
from sklearn.metrics import silhouette_score

# %%
#for kMean
kss= silhouette_score(X, kmeans.labels_)
print("K-means Silhouette Score:", kss)
# Out:
# K-means Silhouette Score: 0.5528190123564095

# %%
#for AgglomerativeClustering
ass= silhouette_score(X,hierarchical.labels_)
print("AgglomerativeClustering Silhouette Score:", ass)
# Out:
# AgglomerativeClustering Silhouette Score: 0.5543236611296419

# %%
#pca
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on Iris dataset')
plt.show()
